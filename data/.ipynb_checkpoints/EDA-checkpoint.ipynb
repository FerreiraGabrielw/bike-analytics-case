# %% [markdown]
# # EDA Inicial - Case Tembici - Gabriel Ferreira

# %%
import pandas as pd

# %% [markdown]
# ## Viagens

# %%
viagens = pd.read_csv("viagens.csv")

# %%
viagens.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90000 entries, 0 to 89999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   project           90000 non-null  object
#  1   customer          90000 non-null  object
#  2   trip              90000 non-null  int64
#  3   start_time        90000 non-null  object
#  4   end_time          90000 non-null  object
#  5   invoice_id        48215 non-null  float64
#  6   invoice_line_id   42559 non-null  float64
#  7   duration_seconds  90000 non-null  int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 5.5+ MB

# %%
viagens.describe()
# Out:
#                trip    invoice_id  invoice_line_id  duration_seconds
# count  9.000000e+04  4.821500e+04     4.255900e+04      9.000000e+04
# mean   5.655363e+07  3.626571e+07     5.578352e+07      4.608835e+03
# std    2.662575e+07  1.876236e+07     2.271609e+07      4.828628e+04
# min    1.049270e+06  1.244390e+06     1.569584e+06      6.100000e+01
# 25%    2.812735e+07  2.996770e+07     3.980890e+07      5.370000e+02
# 50%    7.668805e+07  3.026525e+07     4.014939e+07      9.900000e+02
# 75%    7.695822e+07  5.806788e+07     8.181444e+07      1.961000e+03
# max    7.722521e+07  5.909970e+07     8.300296e+07      1.650673e+06

# %%
viagens.isna().mean().sort_values(ascending=False)
# Out:
# invoice_line_id     0.527122
# invoice_id          0.464278
# project             0.000000
# customer            0.000000
# trip                0.000000
# start_time          0.000000
# end_time            0.000000
# duration_seconds    0.000000
# dtype: float64

# %% [markdown]
# ## Customers

# %%
customers = pd.read_csv("customers.csv")

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177532 entries, 0 to 177531
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   customer                    177532 non-null  object
#  1   project                     177532 non-null  object
#  2   subscription_start_date     177532 non-null  object
#  3   subscription_end_date       177523 non-null  object
#  4   plan_type                   177532 non-null  object
#  5   plan_periodicity            177532 non-null  object
#  6   is_customer_first_purchase  177532 non-null  bool
#  7   is_customer_returning       177395 non-null  object
#  8   plan_cost                   177532 non-null  float64
#  9   user_id                     177516 non-null  object
#  10  date_joined                 177532 non-null  object
# dtypes: bool(1), float64(1), object(9)
# memory usage: 13.7+ MB

# %%
customers.sample(20)
# Out:
#         customer project         subscription_start_date  \
# 141470   118646D       D  2025-11-24 11:22:00.426054 UTC
# 114178    83248D       D         2025-09-12 16:18:45 UTC
# 168601   629862A       A         2025-11-15 09:35:26 UTC
# 114080  3743369D       D         2025-11-23 17:37:59 UTC
# 65754   3757006D       D         2025-11-22 22:18:39 UTC
# 169130  1438655A       A         2025-12-07 01:05:14 UTC
# 172189    84813I       I  2025-11-22 19:38:27.245555 UTC
# 5513     374892D       D         2025-09-15 08:32:50 UTC
# 113734   836161D       D  2025-10-12 17:50:08.916121 UTC
# 56570   2996154D       D         2025-12-02 16:56:52 UTC
# 13235   1190452A       A         2025-12-13 09:54:41 UTC
# 160231  1090225A       A         2025-10-04 20:52:50 UTC
# 85224   3054661D       D  2025-09-30 10:22:24.194785 UTC
# 122921  3563710D       D  2025-09-05 12:40:06.041399 UTC
# 10204    366230A       A         2025-11-03 17:35:24 UTC
# ...

# %%
customers.describe()
# Out:
#            plan_cost
# count  177532.000000
# mean     1251.239686
# std      8391.572015
# min         0.000000
# 25%         0.000000
# 50%        32.000000
# 75%        43.900000
# max    248900.000000

# %%
# converter user_id pra string
customers['user_id'] = customers['user_id'].astype(str)

# %%
customers['user_id'].duplicated().mean()
# Out:
# np.float64(0.6875999819750805)

# %%
customers.to_csv("customers.csv", index=False)

# %% [markdown]
# ## Faturas

# %%
faturas = pd.read_csv("faturas.csv")

# %%
faturas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17757 entries, 0 to 17756
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   invoice_id       17757 non-null  int64
#  1   invoice_line_id  17757 non-null  int64
#  2   project          17757 non-null  object
#  3   invoice_status   17757 non-null  object
#  4   usage_fee        17757 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 693.8+ KB

# %%
faturas.describe()
# Out:
#          invoice_id  invoice_line_id     usage_fee
# count  1.775700e+04     1.775700e+04  17757.000000
# mean   3.203533e+07     4.411879e+07      9.593240
# std    2.457304e+07     3.523096e+07     17.465830
# min    1.244390e+06     1.569613e+06      0.048914
# 25%    3.814045e+06     3.856221e+06      1.980000
# 50%    3.022589e+07     3.995858e+07      6.000000
# 75%    5.818695e+07     8.188185e+07      9.990000
# max    5.867387e+07     8.247967e+07   1100.100000

# %%
faturas.isna().mean().sort_values(ascending=False)
# Out:
# invoice_id         0.0
# invoice_line_id    0.0
# project            0.0
# invoice_status     0.0
# usage_fee          0.0
# dtype: float64

# %%
faturas['invoice_id'].duplicated().mean()
# Out:
# np.float64(0.18088641099284788)

# %%
faturas['invoice_line_id'].duplicated().mean()
# Out:
# np.float64(0.0)

# %% [markdown]
# ## Unlcok_erros

# %%
unlock_erros = pd.read_csv("unlock_erros.csv")

# %%
unlock_erros.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196966 entries, 0 to 196965
# Data columns (total 5 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   user_id          196966 non-null  object
#  1   project          196966 non-null  object
#  2   event_timestamp  196966 non-null  object
#  3   event_name       196966 non-null  object
#  4   error_type       100973 non-null  object
# dtypes: object(5)
# memory usage: 7.5+ MB

# %%
unlock_erros.describe()
# Out:
#          user_id project                 event_timestamp           event_name  \
# count     196966  196966                          196966               196966
# unique     16311      12                           56416                    1
# top     12391392       D  2025-11-03 12:29:56.455003 UTC  unlock_qr_code_fail
# freq         712   95979                              16               196966
#
#                        error_type
# count                      100973
# unique                         40
# top     /bff/qrcode/ebike_warning
# freq                        25440

# %%
unlock_erros.isna().mean().sort_values(ascending=False)
# Out:
# error_type         0.487358
# user_id            0.000000
# project            0.000000
# event_timestamp    0.000000
# event_name         0.000000
# dtype: float64
